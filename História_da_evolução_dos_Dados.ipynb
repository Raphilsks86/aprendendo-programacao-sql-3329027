# %% [markdown]
# <a href="https://colab.research.google.com/github/Raphilsks86/aprendendo-programacao-sql-3329027/blob/main/Hist%C3%B3ria_da_evolu%C3%A7%C3%A3o_dos_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import matplotlib.pyplot as plt

# %%
# eras = [
#     "Antiguidade (4000 a.c.)",
#     "Idade Média (500 - 1500)",
#     "Revolução Industrial (1700)",
#     "Era Digital (1950 - 1990)",
#     "Internet (1990 - 2000)",
#     "Big Data e AI (2010 - presente)"
# ]
# usage = [10, 25, 50, 100, 1000, 10000]

# %%
# # Configuração do gráfico:

# plt.figure(figsize = (10, 6))
# plt.plot(eras, usage, marker = 'o', color = 'blue',label = "Crescimento do uso de Dados")
# plt.title("A história e evolução dos Dados", fontsize = 14)
# plt.xlabel("Período", fontsize = 12)
# plt.ylabel("Volume/Impacto dos Dados (Escala Arbitrária)", fontsize = 12)
# plt.grid(alpha=0.5)
# plt.xticks(rotation = 35, ha = "right")
# plt.legend(fontsize = 12)
# plt.tight_layout()

# plt.show()
